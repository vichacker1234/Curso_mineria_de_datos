# %%
#Se va a usar este cuaderno para el eejrcicio
#Enlace a la siguiente función:
import math
import numpy as np 
import matplotlib.pyplot as plt

# %%
#Se definen algunos parámetros para sen(2x)
x=np.linspace(0,4*math.pi,100)
y=np.sin(2*x)

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel(r'$\sen(x)$')
plt.title("gráfica de sen(x)")
plt.show()

# %%
#Enlace a una imágen
